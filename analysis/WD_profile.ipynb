# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wd_path = '/Users/caritsang/Desktop/FYP/SinglePBH/PBH_M5.0e+14_N6.0e+07/rho01.000e+02.csv'

# %%
df = pd.read_csv(wd_path)
df
# Out:
#       radius       density          mass   temperature       Pphoton  \
# 0       3.86  1.958000e+08  2.386364e-08  1.947180e+06  2.060020e-17
# 1       7.72  1.958310e+08  1.909251e-07  1.455728e+06  6.435287e-18
# 2      11.58  1.958201e+08  6.443923e-07  1.250377e+06  3.502767e-18
# 3      15.44  1.958049e+08  1.527401e-06  1.133873e+06  2.368671e-18
# 4      19.30  1.957853e+08  2.983044e-06  1.057828e+06  1.794349e-18
# ..       ...           ...           ...           ...           ...
# 939  3628.40  5.736480e+03  1.223230e+00  3.554738e+05  2.288113e-20
# 940  3632.26  4.007387e+03  1.223232e+00  3.274086e+05  1.646673e-20
# 941  3636.12  2.478726e+03  1.223233e+00  2.840946e+05  9.334663e-21
# 942  3639.98  1.186098e+03  1.223233e+00  1.700549e+05  1.198405e-21
# 943  3643.84  2.062016e+02  1.223234e+00  5.538153e+03  1.348053e-27
#
#              dPdr
# 0   -3.620821e-14
# 1   -5.059612e-15
# 2   -1.659155e-15
# 3   -7.675303e-16
# 4   -4.275870e-16
# ..            ...
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(7, 3))
ax[0].plot(df['radius'], df['density'])
ax[1].plot(df['radius'], df['temperature'])

ax[0].set_xlabel("Radius (km)")
ax[1].set_xlabel("Radius (km)")

ax[0].set_ylabel(r"Density (g/cm$^{-3}$)")
ax[1].set_ylabel("Temperature (K)")

#plt.suptitle(r"White Dwarf with N=$6\times10^{7}$, $M_\mathrm{PBH}=5\times10^{14}$")
plt.tight_layout()
plt.savefig("../img/profile.pgf")
